# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Инструкция-по-выполнению-проекта" data-toc-modified-id="Инструкция-по-выполнению-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Инструкция по выполнению проекта</a></span><ul class="toc-item"><li><span><a href="#Загрузка-приложений" data-toc-modified-id="Загрузка-приложений-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка приложений</a></span></li><li><span><a href="#Загрузка--файла" data-toc-modified-id="Загрузка--файла-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка  файла</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Общая-информация-о-датафреме" data-toc-modified-id="Общая-информация-о-датафреме-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Общая информация о датафреме</a></span></li><li><span><a href="#Удаление-пропусков" data-toc-modified-id="Удаление-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Удаление пропусков</a></span></li><li><span><a href="#Добавляем-столбцы-в-тест" data-toc-modified-id="Добавляем-столбцы-в-тест-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Добавляем столбцы в тест</a></span></li><li><span><a href="#Проверяем,-что-эффективность-обогащения-рассчитана-правильно" data-toc-modified-id="Проверяем,-что-эффективность-обогащения-рассчитана-правильно-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Проверяем, что эффективность обогащения рассчитана правильно</a></span></li></ul></li><li><span><a href="#Проанализируйте-данные" data-toc-modified-id="Проанализируйте-данные-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проанализируйте данные</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-на-этапах-очистки" data-toc-modified-id="Изменение-концентрации-металлов-на-этапах-очистки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изменение концентрации металлов на этапах очистки</a></span></li><li><span><a href="#Распределения-размеров-гранул-сырья" data-toc-modified-id="Распределения-размеров-гранул-сырья-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределения размеров гранул сырья</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение модели</a></span><ul class="toc-item"><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-градиентного-бустинга" data-toc-modified-id="Модель-градиентного-бустинга-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Модель градиентного бустинга</a></span></li><li><span><a href="#Вычисление-итоговой-sMAPE" data-toc-modified-id="Вычисление-итоговой-sMAPE-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Вычисление итоговой sMAPE</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. В вашем распоряжении данные с параметрами добычи и очистки.
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
# Вам нужно:
#
#     Подготовить данные;
#     Провести исследовательский анализ данных;
#     Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам pandas, matplotlib и sklearn. Вам поможет их документация.
# Следующий урок посвящён технологическому процессу очистки руды. Решите сами, какие детали нужны для построения модели, а какие — нет.
#
# Опишем каждую стадию:
# 1. Флотация
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
# 2. Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# Описание данных
#
# Технологический процесс
#
#     Rougher feed — исходное сырье
#     Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     Xanthate **— ксантогенат (промотер, или активатор флотации);
#     Sulphate — сульфат (на данном производстве сульфид натрия);
#     Depressant — депрессант (силикат натрия).
#     Rougher process (англ. «грубый процесс») — флотация
#     Rougher tails — отвальные хвосты
#     Float banks — флотационная установка
#     Cleaner process — очистка
#     Rougher Au — черновой концентрат золота
#     Final Au — финальный концентрат золота
#
# Параметры этапов
#
#     air amount — объём воздуха
#     fluid levels — уровень жидкости
#     feed size — размер гранул сырья
#     feed rate — скорость подачи
#
# Наименование признаков
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
#
# Возможные значения для блока [этап]:
#
#     rougher — флотация
#     primary_cleaner — первичная очистка
#     secondary_cleaner — вторичная очистка
#     final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
#     input — параметры сырья
#     output — параметры продукта
#     state — параметры, характеризующие текущее состояние этапа
#     calculation — расчётные характеристики

# %% [markdown]
# ## Инструкция по выполнению проекта

# %% [markdown]
# 1. Подготовьте данные
#
#     1.1. Откройте файлы и изучите их.
#
#     1.2. Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
#
#     1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
#
#     1.4. Проведите предобработку данных.
#
# 2. Проанализируйте данные
#
#     2.1. Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
#
#     2.2. Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
#     2.3. Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# 3. Постройте модель
#
#     3.1. Напишите функцию для вычисления итоговой sMAPE.
#
#     3.2. Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# ### Загрузка приложений

# %%
import os

import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from IPython import get_ipython
ipython = get_ipython()


# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload
# %autoreload 2

#ml
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import StratifiedKFold, KFold

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_validate

from sklearn.metrics import DetCurveDisplay, RocCurveDisplay

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns 

import plotly
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)


import warnings 
warnings.filterwarnings("ignore")

pd.options.mode.chained_assignment = None
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#немного опций для удобства

pd.options.display.max_rows = 9
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

large = 16; med = 12; small = 10
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (12, 8),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}

plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')

sns.set_palette('deep') 
sns.set_style("whitegrid")

from matplotlib import rcParams, rcParamsDefault

rcParams['figure.figsize'] = 12,12
# %config InlineBackend.figure_format = 'svg' 
# %matplotlib inline
factor = 10
default_dpi = rcParamsDefault['figure.dpi']
rcParams['figure.dpi'] = default_dpi*factor

# %% [markdown]
# ### Загрузка  файла

# %%
# загружаем файлы

pth1='/home/alexandra/data_science/gold_recovery_test_new.csv'
pth2='/datasets/gold_recovery_test_new.csv'
pth3='https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv'

try:
  
    if os.path.exists(pth1):
        df_test = pd.read_csv(pth1, delimiter='\,')
    elif os.path.exists(pth2):
        df_test = pd.read_csv(pth2, delimiter='\,')
    # elif os.path.exists(pth3):
    #     df = pd.read_csv(pth3, delimiter='\,')
    else:
        df_test = pd.read_csv(pth3, delimiter='\,')
  
    print('Загрузка файла gold_recovery_test_new.csv прошла успешно')      
except:
    print('Ошибка загрузки файла. Проверьте путь к файлу.')

pth1='/home/alexandra/data_science/gold_recovery_full_new.csv'
pth2='/datasets/gold_recovery_full_new.csv'
pth3='https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv'

try:
  
    if os.path.exists(pth1):
        df = pd.read_csv(pth1, delimiter='\,')
    elif os.path.exists(pth2):
        df = pd.read_csv(pth2, delimiter='\,')
    # elif os.path.exists(pth3):
    #     df = pd.read_csv(pth3, delimiter='\,')
    else:
        df = pd.read_csv(pth3, delimiter='\,')
  
    print('Загрузка файла gold_recovery_full_new.csv прошла успешно')      
except:
    print('Ошибка загрузки файла. Проверьте путь к файлу.')

pth1='/home/alexandra/data_science/gold_recovery_train_new.csv'
pth2='/datasets/gold_recovery_train_new.csv'
pth3='https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv'

try:
  
    if os.path.exists(pth1):
        df_train = pd.read_csv(pth1, delimiter='\,')
    elif os.path.exists(pth2):
        df_train = pd.read_csv(pth2, delimiter='\,')
    # elif os.path.exists(pth3):
    #     df = pd.read_csv(pth3, delimiter='\,')
    else:
        df_train = pd.read_csv(pth3, delimiter='\,')
  
    print('Загрузка файла gold_recovery_train_new.csv прошла успешно')      
except:
    print('Ошибка загрузки файла. Проверьте путь к файлу.')
# Out:
# Загрузка файла gold_recovery_test_new.csv прошла успешно
# Загрузка файла gold_recovery_full_new.csv прошла успешно
# Загрузка файла gold_recovery_train_new.csv прошла успешно

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Общая информация о датафреме

# %%
df
df_test
df_train
# Out:
#                       date  final.output.concentrate_ag  \
# 0      2016-01-15 00:00:00                     6.055403
# 1      2016-01-15 01:00:00                     6.029369
# 2      2016-01-15 02:00:00                     6.055926
# 3      2016-01-15 03:00:00                     6.047977
# ...                    ...                          ...
# 19435  2018-08-18 07:59:59                     3.195978
# 19436  2018-08-18 08:59:59                     3.109998
# 19437  2018-08-18 09:59:59                     3.367241
# 19438  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                         9.889648                      5.507324
# 1                         9.968944                      5.257781
# 2                        10.213995                      5.383759
# 3                         9.977019                      4.858634
# ...                            ...                           ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
df.shape
df_test.shape
df_train.shape
# Out:
# (19439, 87)
# (5290, 53)
# (14149, 87)

# %% [markdown]
# ---
#
#
# Судя по всему, целевыми признаками у нас будут являтся:
#
#     -rougher.output.recovery
#     -final.output.recovery
#
# И в тестовой выборке df_test оба эти параметра отсутствуют
#
#
# ---

# %% [markdown]
# ### Удаление пропусков

# %%
# заполняем пропуски по соседним значениям

df=df.fillna(method='ffill')
df_test=df_test.fillna(method='ffill')
df_train=df_train.fillna(method='ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19439 non-null  float64
#  2   final.output.concentrate_pb                         19439 non-null  float64
#  3   final.output.concentrate_sol                        19439 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19439 non-null  float64
#  7   final.output.tail_pb                                19439 non-null  float64
# ...

# %% [markdown]
# ### Добавляем столбцы в тест

# %%
#1.3. Проанализируйте признаки, недоступные в тестовой выборке

df_col=df.columns
df_test_col=df_test.columns
tmp=[]
#df_tmp = df1.append(df2[df1.columns]).drop_duplicates(keep=False)
for i in df_col:
    if i in df_test_col:
        continue
    else:
        tmp.append(i)

tmp
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В тестовой выборке отсутствуют данные о результатаъх каждого этапа очистки. Следовательно, это то, что нам надо предсказать. И мы их не знаем изначально.

# %%
df_tmp=df[['rougher.output.recovery', 'final.output.recovery', 'date']]
df_tmp
df_test=df_test.merge(df_tmp, how='inner', on='date')
# Out:
#        rougher.output.recovery  final.output.recovery                 date
# 0                    87.107763              70.541216  2016-01-15 00:00:00
# 1                    86.843261              69.266198  2016-01-15 01:00:00
# 2                    86.842308              68.116445  2016-01-15 02:00:00
# 3                    87.226430              68.347543  2016-01-15 03:00:00
# ...                        ...                    ...                  ...
# 19435                87.724007              69.049291  2018-08-18 07:59:59
# 19436                88.890579              67.002189  2018-08-18 08:59:59
# 19437                89.858126              65.523246  2018-08-18 09:59:59
# 19438                89.514960              70.281454  2018-08-18 10:59:59
#
# [19439 rows x 3 columns]

# %% [markdown]
# ### Проверяем, что эффективность обогащения рассчитана правильно

# %%
#Вычислите её на обучающей выборке для признака rougher.output.recovery. 
#Найдите MAE между вашими расчётами и значением признака. 
#Опишите выводы.

df_train['recovery']=100*df_train['rougher.output.concentrate_au']*(
    df_train['rougher.input.feed_au']-df_train['rougher.output.tail_au'])/(
    df_train['rougher.input.feed_au']*(df_train['rougher.output.concentrate_au']-df_train['rougher.output.tail_au']))

# %%
df_train
# Out:
#                       date  final.output.concentrate_ag  \
# 0      2016-01-15 00:00:00                     6.055403
# 1      2016-01-15 01:00:00                     6.029369
# 2      2016-01-15 02:00:00                     6.055926
# 3      2016-01-15 03:00:00                     6.047977
# ...                    ...                          ...
# 14145  2018-08-18 07:59:59                     3.195978
# 14146  2018-08-18 08:59:59                     3.109998
# 14147  2018-08-18 09:59:59                     3.367241
# 14148  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                         9.889648                      5.507324
# 1                         9.968944                      5.257781
# 2                        10.213995                      5.383759
# 3                         9.977019                      4.858634
# ...                            ...                           ...
# ...

# %%
mae=mean_absolute_error(df_train['recovery'],df_train['rougher.output.recovery'])

print('Средняя абсолютная ошибка =', mae)
# Out:
# Средняя абсолютная ошибка = 1.1498046842860452e-14

# %% [markdown]
# ---
# Ошибка очень низкая, то есть эффективность обогащения расчитана правильно.
#
#
#
# ---

# %% [markdown]
# ## Проанализируйте данные

# %% [markdown]
# ###  Изменение концентрации металлов на этапах очистки

# %%
#Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. 
#Опишите выводы.

#sns.set(rc={'figure.figsize':(12,10)})
#sns.histplot(data=df_au, bins=100)

df_au=df[['rougher.input.feed_au', 'rougher.output.concentrate_au','primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']]
labels=['Начальная концентрация', 'Концентрация после флотации', 'Концентрация после первичной очистки', 'Финальная концентрация']

df_au.plot.hist(bins=100, figsize=(10, 6), ylim=(0,3000))
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение концентрации золота (Au) по этапам очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение концентрации золота (Au) по этапам очистки')

# %%
df_ag=df[['rougher.input.feed_ag', 'rougher.output.concentrate_ag','primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']]
labels=['Начальная концентрация', 'Концентрация после флотации', 'Концентрация после первичной очистки', 'Финальная концентрация']

df_ag.plot.hist(bins=100, figsize=(10, 6), ylim=(0,1700), alpha = 0.6)
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение концентрации серебра (Ag) по этапам очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение концентрации серебра (Ag) по этапам очистки')

# %%
df_pb=df[['rougher.input.feed_pb', 'rougher.output.concentrate_pb','primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']]
labels=['Начальная концентрация', 'Концентрация после флотации', 'Концентрация после первичной очистки', 'Финальная концентрация']

df_pb.plot.hist(bins=100, figsize=(10, 6), ylim=(0,1500), alpha = 0.6)
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение концентрации свинца (Pb) по этапам очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение концентрации свинца (Pb) по этапам очистки')

# %%
#постоим среднюю концентрацию исследуемых элементов
au_mean=[]
for col_name in df_au.columns:
    au_mean.append(df[col_name].mean())
au_mean=pd.Series(au_mean, name='Золото')

ag_mean=[]
for col_name in df_ag.columns:
    ag_mean.append(df[col_name].mean())
ag_mean=pd.Series(ag_mean, name='Серебро')

pb_mean=[]
for col_name in df_pb.columns:
    pb_mean.append(df[col_name].mean())
pb_mean=pd.Series(pb_mean, name='Свинец')

# %%
name = pd.Series(['До очистки', 'После флотации', 'После первого этапа', 'Финальная'])

concentrations=pd.concat([name, au_mean, ag_mean, pb_mean], axis= 1)
concentrations
# Out:
#                      0     Золото    Серебро    Свинец
# 0           До очистки   8.266097   8.794927  3.585096
# 1       После флотации  19.772000  11.994759  7.606272
# 2  После первого этапа  32.119400   8.442408  9.810317
# 3            Финальная  44.076513   5.168387  9.978821

# %%
concentrations.plot(marker='o')
plt.title('Распределение средних концентраций примесей по этапам очистки', fontsize=14)
# Out:
# <AxesSubplot: >
# Text(0.5, 1.0, 'Распределение средних концентраций примесей по этапам очистки')

# %% [markdown]
# ---
# После всех этапов очистки концентрация золота возрастает, а концентрация других элементов - уменьшается.
#
#
# ---

# %% [markdown]
# ### Распределения размеров гранул сырья

# %%
# Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. 
#Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.



labels=['Обучающая выборка', 'Тестовая выборка']
df_train['rougher.input.feed_size'].plot.hist(bins=100, figsize=(10, 6), xlim=(0,200), alpha = 0.6, density=True)
df_test['rougher.input.feed_size'].plot.hist(bins=100, alpha = 0.6, density=True)
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение размеров гранул сырья  до очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение размеров гранул сырья  до очистки')

# %%
labels=['Обучающая выборка', 'Тестовая выборка']
df_train['primary_cleaner.input.feed_size'].plot.hist(bins=100, figsize=(10, 6), xlim=(2,12), alpha = 0.6, density=True)
df_test['primary_cleaner.input.feed_size'].plot.hist(bins=100, alpha = 0.6, density=True)
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение размеров гранул сырья на после первичной очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение размеров гранул сырья на после первичной очистки')

# %% [markdown]
# ---
#
#
# Вывод: размер гранул в выборках совпадает.
#
#
# ---

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
df_sum=df
df_sum['rougher.input.conc']=df_sum['rougher.input.feed_ag']+df_sum['rougher.input.feed_au']+df_sum['rougher.input.feed_pb']+df_sum['rougher.input.feed_sol']
df_sum['rougher.output.conc']=df_sum['rougher.output.concentrate_ag']+df_sum['rougher.output.concentrate_au']+df_sum['rougher.output.concentrate_pb']+df_sum['rougher.output.concentrate_sol']
df_sum['primary_cleaner.output.conc']=df_sum['primary_cleaner.output.concentrate_ag']+df_sum['primary_cleaner.output.concentrate_au']+df_sum['primary_cleaner.output.concentrate_pb']+df_sum['primary_cleaner.output.concentrate_sol']
df_sum['final.output.conc']=df_sum['final.output.concentrate_ag']+df_sum['final.output.concentrate_au']+df_sum['final.output.concentrate_pb']+df_sum['final.output.concentrate_sol']

df_sum=df_sum[['rougher.input.conc', 'rougher.output.conc', 'primary_cleaner.output.conc', 'final.output.conc']]

df_sum
# Out:
#        rougher.input.conc  rougher.output.conc  primary_cleaner.output.conc  \
# 0               51.680034            66.424950                    72.640924
# 1               50.659114            67.012710                    72.543485
# 2               50.609929            66.103793                    72.095042
# 3               51.061546            65.752751                    59.957723
# ...                   ...                  ...                          ...
# 19435           53.696482            70.539603                    59.703912
# 19436           54.589604            55.376330                    59.561096
# 19437           54.027355            69.201689                    57.216686
# 19438           53.535054            69.544003                    55.748041
#
#        final.output.conc
# 0              63.644396
# 1              63.957723
# 2              64.311180
# 3              63.573449
# ...                  ...
# 19435          68.274362
# ...

# %%
labels=['Начальная концентрация', 'Концентрация после флотации', 'Концентрация после первичной очистки', 'Финальная концентрация']

df_sum.plot.hist(bins=100, figsize=(10, 6), alpha = 0.6)
#features_valid['Balance'].plot.hist(bins=100)
plt.legend(labels)
plt.title('Распределение концентрации примесей по этапам очистки', fontsize=14)
plt.show()
# Out:
# <AxesSubplot: ylabel='Frequency'>
# Text(0.5, 1.0, 'Распределение концентрации примесей по этапам очистки')

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %%
#сравняем количество столбцов на тестовой и тренировочной выборках

df_train_new=df_train[df_test.columns]

df_test=df_test.drop('date', axis=1)
df_train_new=df_train_new.drop('date', axis=1)


df_train_new.shape
df_test.shape 
#df_test.info()
# Out:
# (14149, 54)
# (5290, 54)

# %%
# веделяем из выборок два целевых признака

target_test_rouger = df_test['rougher.output.recovery']
features_test_rouger = df_test.drop('rougher.output.recovery', axis=1)

target_test_final = df_test['final.output.recovery']
features_test_final = df_test.drop('final.output.recovery', axis=1)

target_train_new_rouger = df_train_new['rougher.output.recovery']
features_train_new_rouger = df_train_new.drop('rougher.output.recovery', axis=1)

target_train_new_final = df_train_new['final.output.recovery']
features_train_new_final = df_train_new.drop('final.output.recovery', axis=1)

# %%
# напишем функцию для sMAPE
from sklearn.metrics import make_scorer
smape_error=0
def smape (p, t):
    smape_error= np.sum(np.abs(t-p)/(np.abs(p)+np.abs(t)))*(200/len(p))
    return smape_error

smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# #### Модель случайного леса

# %%
# строим модель случайного леса и ищем гиперпараметры.
# сначала грубая оценка более быстрым RandomizedSearchCV
# затем используем GridSearchCV с более мелкой сеткой для уточнения

model_forest = RandomForestRegressor(random_state=12345)
params_forest = {'max_depth':range(1,15,4), 'n_estimators':range(10, 150,30), 'min_samples_leaf':range(10,80,20)}
grid_model = RandomizedSearchCV(model_forest, params_forest, cv=3, scoring = smape_scorer, verbose=2, n_jobs=-1, n_iter = 40) #verbose показывает время

grid_model.fit(features_train_new_rouger, target_train_new_rouger)

grid_model.best_score_
grid_model.best_estimator_
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [CV] END ..max_depth=5, min_samples_leaf=10, n_estimators=40; total time=   5.5s
# [CV] END ..max_depth=5, min_samples_leaf=10, n_estimators=40; total time=   5.4s
# [CV] END ..max_depth=5, min_samples_leaf=10, n_estimators=40; total time=   5.3s
# [CV] END ..max_depth=5, min_samples_leaf=30, n_estimators=10; total time=   1.3s
# [CV] END ..max_depth=5, min_samples_leaf=30, n_estimators=10; total time=   1.3s
# [CV] END ..max_depth=5, min_samples_leaf=30, n_estimators=10; total time=   1.3s
# [CV] END max_depth=13, min_samples_leaf=50, n_estimators=130; total time=  31.0s
# [CV] END max_depth=13, min_samples_leaf=50, n_estimators=130; total time=  24.9s
# [CV] END max_depth=13, min_samples_leaf=50, n_estimators=130; total time=  26.7s
# [CV] END .max_depth=5, min_samples_leaf=70, n_estimators=100; total time=  13.0s
# [CV] END .max_depth=5, min_samples_leaf=70, n_estimators=100; total time=  12.5s
# ...

# %%
# построим визуальные распределения наших гиперпараметров и обберем лучшие интервалы

rs_df = pd.DataFrame(grid_model.cv_results_).sort_values('rank_test_score').reset_index(drop=True)


rs_df['param_n_estimators'] = pd.to_numeric(rs_df['param_n_estimators'])
rs_df['param_max_depth'] = pd.to_numeric(rs_df['param_max_depth'])
rs_df['param_min_samples_leaf'] = pd.to_numeric(rs_df['param_min_samples_leaf'])
#rs_df['mean_test_score']=rs_df['mean_test_score']*(-1)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,3))
sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, color='lightpink', ax=axes[0])
sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, color='lightgreen', ax=axes[1])
sns.barplot(x='param_min_samples_leaf', y='mean_test_score', data=rs_df, color='red', ax=axes[2])
plt.show
# Out:
# <AxesSubplot:xlabel='param_max_depth', ylabel='mean_test_score'>
# <AxesSubplot:xlabel='param_n_estimators', ylabel='mean_test_score'>
# <AxesSubplot:xlabel='param_min_samples_leaf', ylabel='mean_test_score'>
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model_forest = RandomForestRegressor(random_state=12345)
params_forest = {'max_depth':range(9,11), 'n_estimators':range(10,40,10), 'min_samples_leaf':range(50,60,5)}
grid_model = GridSearchCV(model_forest, params_forest, cv=5, scoring = smape_scorer,verbose=2) #verbose показывает время

grid_model.fit(features_train_new_rouger, target_train_new_rouger)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=10; total time=   2.5s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=10; total time=   2.4s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=10; total time=   2.3s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=10; total time=   2.4s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=10; total time=   2.5s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=20; total time=   5.3s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=20; total time=   5.3s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=20; total time=   4.8s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=20; total time=   4.9s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=20; total time=   4.9s
# [CV] END ..max_depth=9, min_samples_leaf=50, n_estimators=30; total time=   7.5s
# ...

# %%
grid_model.best_score_
forest_r=grid_model.best_estimator_

# %% [markdown]
# #### Модель градиентного бустинга

# %%
# gbr = GradientBoostingRegressor(random_state=12345)
# params_gbr = {'max_depth':range(1,15,3), 'n_estimators':range(10, 200,20)}
# grid_model = RandomizedSearchCV(gbr, params_gbr, cv=3, scoring = smape_scorer, n_iter = 30, verbose=2)

# grid_model.fit(features_train_new_rouger, target_train_new_rouger)

# grid_model.best_score_
# grid_model.best_estimator_
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] END ......................max_depth=4, n_estimators=190; total time=  34.3s
# [CV] END ......................max_depth=4, n_estimators=190; total time=  33.7s
# [CV] END ......................max_depth=4, n_estimators=190; total time=  35.7s
# [CV] END .......................max_depth=4, n_estimators=10; total time=   1.9s
# [CV] END .......................max_depth=4, n_estimators=10; total time=   1.8s
# [CV] END .......................max_depth=4, n_estimators=10; total time=   1.8s
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.4min
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.3min
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.3min
# [CV] END ......................max_depth=7, n_estimators=190; total time=  59.2s
# [CV] END ......................max_depth=7, n_estimators=190; total time=  59.2s
# ...

# %%
# grid_model.best_score_
# grid_model.best_estimator_
# Out:
# -11.01881841011731
# GradientBoostingRegressor(max_depth=1, n_estimators=70, random_state=12345)

# %%
# rs_df = pd.DataFrame(grid_model.cv_results_).sort_values('rank_test_score').reset_index(drop=True)


# rs_df['param_n_estimators'] = pd.to_numeric(rs_df['param_n_estimators'])
# rs_df['param_max_depth'] = pd.to_numeric(rs_df['param_max_depth'])

# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,3))
# sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, color='lightpink', ax=axes[0])
# sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, color='lightgreen', ax=axes[1])
# plt.show
# Out:
# <AxesSubplot:xlabel='param_max_depth', ylabel='mean_test_score'>
# <AxesSubplot:xlabel='param_n_estimators', ylabel='mean_test_score'>
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GradientBoostingRegressor(random_state=12345)
params_gbr = {'max_depth':range(1,4), 'n_estimators':range(10,50,10)}
grid_model = GridSearchCV(gbr, params_gbr, cv=5, scoring = smape_scorer,verbose=2) #verbose показывает время

grid_model.fit(features_train_new_rouger, target_train_new_rouger)

grid_model.best_score_
gbr_r=grid_model.best_estimator_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.8s
# ...

# %%
# для 'final.output.recovery' буду использовать модель град.бустинга как показавшую лучший результат.
# gbr = GradientBoostingRegressor(random_state=12345)
# params_gbr = {'max_depth':range(1,15,3), 'n_estimators':range(10, 200,20)}
# grid_model = RandomizedSearchCV(gbr, params_gbr, cv=3, scoring = smape_scorer, n_iter = 30, verbose=2)

# grid_model.fit(features_train_new_final, target_train_new_final)

# grid_model.best_score_
# grid_model.best_estimator_
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] END ......................max_depth=1, n_estimators=110; total time=   5.3s
# [CV] END ......................max_depth=1, n_estimators=110; total time=   5.4s
# [CV] END ......................max_depth=1, n_estimators=110; total time=   5.3s
# [CV] END .....................max_depth=10, n_estimators=190; total time= 1.4min
# [CV] END .....................max_depth=10, n_estimators=190; total time= 1.3min
# [CV] END .....................max_depth=10, n_estimators=190; total time= 1.3min
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.3min
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.3min
# [CV] END .....................max_depth=13, n_estimators=150; total time= 1.3min
# [CV] END .....................max_depth=10, n_estimators=150; total time= 1.0min
# [CV] END .....................max_depth=10, n_estimators=150; total time= 1.0min
# ...

# %% [markdown]
# <font color='purple'><b>Комментарий студента: я закоментировала некоторые ячейки для экономии времени при прогонке кода. В общем то смысл их онятен - это грубыя оценка</b></font>

# %%
# grid_model.best_score_
# grid_model.best_estimator_
# Out:
# -9.593957979524918
# GradientBoostingRegressor(max_depth=1, n_estimators=30, random_state=12345)

# %%
# rs_df = pd.DataFrame(grid_model.cv_results_).sort_values('rank_test_score').reset_index(drop=True)


# rs_df['param_n_estimators'] = pd.to_numeric(rs_df['param_n_estimators'])
# rs_df['param_max_depth'] = pd.to_numeric(rs_df['param_max_depth'])

# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,3))
# sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, color='lightpink', ax=axes[0])
# sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, color='lightgreen', ax=axes[1])
# plt.show
# Out:
# <AxesSubplot:xlabel='param_max_depth', ylabel='mean_test_score'>
# <AxesSubplot:xlabel='param_n_estimators', ylabel='mean_test_score'>
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GradientBoostingRegressor(random_state=12345)
params_gbr = {'max_depth':range(1,4), 'n_estimators':range(10,40,10)}
grid_model = GridSearchCV(gbr, params_gbr, cv=5, scoring = smape_scorer,verbose=2) #verbose показывает время

grid_model.fit(features_train_new_final, target_train_new_final)

grid_model.best_score_
gbr_f=grid_model.best_estimator_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=20; total time=   1.2s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.8s
# ...

# %%
from sklearn.dummy import DummyRegressor

dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train_new_rouger, target_train_new_rouger)

p=dummy_regr.predict(features_test_rouger)
smape_dummy=smape(p, target_test_rouger)
print('sMAPE_router для дамми регрессора:',smape_dummy)

dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train_new_final, target_train_new_final)

p=dummy_regr.predict(features_test_final)
smape_dummy=smape(p, target_test_final)
print('sMAPE_final для дамми регрессора:',smape_dummy)
# Out:
# DummyRegressor()
# sMAPE_router для дамми регрессора: 10.379799283438494
# DummyRegressor()
# sMAPE_final для дамми регрессора: 10.25957407354855

# %%
df = pd.DataFrame({'Модель': ['Флотация'], 
                   'Случайный лес': [5.02],
                   "Градиентный бустинг":[10.27],
                   'Dummy':[10.38]})

df
# Out:
#      Модель  Случайный лес  Градиентный бустинг  Dummy
# 0  Флотация           5.02                10.27  10.38

# %% [markdown]
# ---
# По результатам проведенных расчетов обе модели показади результат лучше дамми-регрессора. Наименьшую величину показал градиентный бустинг. Его и выберем дла дальнейших исследований.
#
# ---

# %% [markdown]
# #### Вычисление итоговой sMAPE

# %%
model = gbr_r
model.fit(features_train_new_rouger, target_train_new_rouger)
preds = model.predict(features_test_rouger)

smape_rougher=smape(preds, target_test_rouger)

print('sMAPE для процесса флотации:',smape_rougher)
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=40, random_state=12345)
# sMAPE для процесса флотации: 8.525264452269232

# %%
model = gbr_f
model.fit(features_train_new_final, target_train_new_final)
preds = model.predict(features_test_final)

smape_final=smape(preds, target_test_final)

print('sMAPE для финального процесса:',smape_final)
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=30, random_state=12345)
# sMAPE для финального процесса: 7.995728501111642

# %%
smape_total=0.25*smape_rougher+0.75*smape_final
print('Итоговое sMAPE:',smape_total)
# Out:
# Итоговое sMAPE: 8.128112488901039

# %% [markdown]
# ### Выводы

# %% [markdown]
# В работе были проведены исследования золотодобычи на предприятии. По результатам исследования подготовлена модель, предсказывающая коэффициент восстановления золота из золотосодержащей руды со sMAPE равным 20,5.
